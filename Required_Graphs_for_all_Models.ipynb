# %% [markdown]
# <a href="https://colab.research.google.com/github/zihan07/Research-of-Semantic-similarity-between-Quran-verses-with-Biographies/blob/Final-Code-of-the-Research/Required_Graphs_for_all_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt

# List of window frames to evaluate
window_frames = ['V1_B1', 'V1_B3', 'V1_B5', 'V1_B7',
                 'V3_B1', 'V3_B3', 'V3_B5', 'V3_B7',
                 'V5_B1', 'V5_B3', 'V5_B5', 'V5_B7',
                 'V7_B1', 'V7_B3', 'V7_B5', 'V7_B7']

# List of file paths
file_paths = [
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b7.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b7.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b7.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b7.xlsx'
]

# Create a figure with subplots
fig, axes = plt.subplots(4, 4, figsize=(20, 20))  # 4x4 grid of subplots
fig.suptitle('Threshold vs Accuracy for Different Window Frames', fontsize=16)

# Loop through each file and plot the data in its respective subplot
for i, (file_path, window_frame) in enumerate(zip(file_paths, window_frames)):
    # Read the Excel file
    df = pd.read_excel(file_path)

    # Determine the subplot position
    row = i // 4
    col = i % 4

    # Plot the threshold vs accuracy in the subplot
    axes[row, col].plot(df['Threshold'], df['Accuracy'])
    axes[row, col].set_title(window_frame)
    axes[row, col].set_xlabel('Threshold')
    axes[row, col].set_ylabel('Accuracy')

# Adjust layout to prevent overlap
plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust the rect to make space for the main title

# Save the plot as a PNG file in Google Drive
save_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/threshold_vs_accuracy.png'  # Specify your desired path in Google Drive
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

print(f"Plot saved to Google Drive at: {save_path}")
# Out:
# Plot saved to Google Drive at: /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/threshold_vs_accuracy.png

# %% [markdown]
# # **Accuracy**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive

# List of window frames to evaluate
window_frames = ['V1_B1', 'V1_B3', 'V1_B5', 'V1_B7',
                 'V3_B1', 'V3_B3', 'V3_B5', 'V3_B7',
                 'V5_B1', 'V5_B3', 'V5_B5', 'V5_B7',
                 'V7_B1', 'V7_B3', 'V7_B5', 'V7_B7']

# List of file paths
file_paths = [
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b7.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b7.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b7.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b7.xlsx'
]

# Define color and line style mappings
color_map = {
    'V1': 'red',
    'V3': 'yellow',
    'V5': 'blue',
    'V7': 'orange'
}

line_style_map = {
    'B1': '-',  # Solid line
    'B3': '--', # Dashed line
    'B5': ':',  # Dotted line
    'B7': '-.'  # Dash-dot line
}

# Create a figure and axis
plt.figure(figsize=(12, 8))

# Loop through each file and plot the data
for file_path, window_frame in zip(file_paths, window_frames):
    # Extract V and B from the window_frame
    v_part = window_frame.split('_')[0]  # e.g., 'V1'
    b_part = window_frame.split('_')[1]  # e.g., 'B1'

    # Get the corresponding color and line style
    color = color_map[v_part]
    line_style = line_style_map[b_part]

    # Read the Excel file
    df = pd.read_excel(file_path)

    # Plot the threshold vs accuracy with the corresponding color and line style
    plt.plot(df['Threshold'], df['Accuracy'], label=window_frame, color=color, linestyle=line_style)

# Add labels and title
plt.xlabel('Threshold')
plt.ylabel('Accuracy')
# plt.title('Threshold vs Accuracy for Different Window Frames')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')  # Place legend outside the plot

# Save the plot as a PNG file in Google Drive
save_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/threshold_vs_accuracy_All.png'  # Specify your desired path in Google Drive
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

print(f"Plot saved to Google Drive at: {save_path}")
# Out:
# Plot saved to Google Drive at: /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/threshold_vs_accuracy_All.png

# %% [markdown]
# # **Precision (Mecca)**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# List of window frames to evaluate
window_frames = ['V1_B1', 'V1_B3', 'V1_B5', 'V1_B7',
                 'V3_B1', 'V3_B3', 'V3_B5', 'V3_B7',
                 'V5_B1', 'V5_B3', 'V5_B5', 'V5_B7',
                 'V7_B1', 'V7_B3', 'V7_B5', 'V7_B7']

# List of file paths
file_paths = [
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b7.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b7.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b7.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b7.xlsx'
]

# Define color and line style mappings
color_map = {
    'V1': 'red',
    'V3': 'yellow',
    'V5': 'blue',
    'V7': 'orange'
}

line_style_map = {
    'B1': '-',  # Solid line
    'B3': '--', # Dashed line
    'B5': ':',  # Dotted line
    'B7': '-.'  # Dash-dot line
}

# Create a figure and axis
plt.figure(figsize=(12, 8))

# Loop through each file and plot the data
for file_path, window_frame in zip(file_paths, window_frames):
    # Extract V and B from the window_frame
    v_part = window_frame.split('_')[0]  # e.g., 'V1'
    b_part = window_frame.split('_')[1]  # e.g., 'B1'

    # Get the corresponding color and line style
    color = color_map[v_part]
    line_style = line_style_map[b_part]

    # Read the Excel file
    df = pd.read_excel(file_path)

    # Plot the threshold vs Precision with the corresponding color and line style
    plt.plot(df['Threshold'], df['Precision (Mecca)'], label=window_frame, color=color, linestyle=line_style)

# Add labels and title
plt.xlabel('Threshold')
plt.ylabel('Meccan Precision')
# plt.title('Threshold vs Precision for Different Window Frames')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')  # Place legend outside the plot

# Save the plot as a PNG file in Google Drive
save_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/threshold_vs_Precision_(Mecca)_All.png'  # Specify your desired path in Google Drive
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

print(f"Plot saved to Google Drive at: {save_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Plot saved to Google Drive at: /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/threshold_vs_Precision_(Mecca)_All.png

# %% [markdown]
# # **Recall (Mecca)**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# List of window frames to evaluate
window_frames = ['V1_B1', 'V1_B3', 'V1_B5', 'V1_B7',
                 'V3_B1', 'V3_B3', 'V3_B5', 'V3_B7',
                 'V5_B1', 'V5_B3', 'V5_B5', 'V5_B7',
                 'V7_B1', 'V7_B3', 'V7_B5', 'V7_B7']

# List of file paths
file_paths = [
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b7.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b7.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b7.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b7.xlsx'
]

# Define color and line style mappings
color_map = {
    'V1': 'red',
    'V3': 'yellow',
    'V5': 'blue',
    'V7': 'orange'
}

line_style_map = {
    'B1': '-',  # Solid line
    'B3': '--', # Dashed line
    'B5': ':',  # Dotted line
    'B7': '-.'  # Dash-dot line
}

# Create a figure and axis
plt.figure(figsize=(12, 8))

# Loop through each file and plot the data
for file_path, window_frame in zip(file_paths, window_frames):
    # Extract V and B from the window_frame
    v_part = window_frame.split('_')[0]  # e.g., 'V1'
    b_part = window_frame.split('_')[1]  # e.g., 'B1'

    # Get the corresponding color and line style
    color = color_map[v_part]
    line_style = line_style_map[b_part]

    # Read the Excel file
    df = pd.read_excel(file_path)

    # Plot the threshold vs Recall with the corresponding color and line style
    plt.plot(df['Threshold'], df['Recall (Mecca)'], label=window_frame, color=color, linestyle=line_style)

# Add labels and title
plt.xlabel('Threshold')
plt.ylabel('Meccan Recall')
# plt.title('Threshold vs Precision for Different Window Frames')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')  # Place legend outside the plot

# Save the plot as a PNG file in Google Drive
save_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/threshold_vs_Recall_(Mecca)_All.png'  # Specify your desired path in Google Drive
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

print(f"Plot saved to Google Drive at: {save_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Plot saved to Google Drive at: /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/threshold_vs_Recall_(Mecca)_All.png

# %% [markdown]
# # **F1 Score (Mecca)**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# List of window frames to evaluate
window_frames = ['V1_B1', 'V1_B3', 'V1_B5', 'V1_B7',
                 'V3_B1', 'V3_B3', 'V3_B5', 'V3_B7',
                 'V5_B1', 'V5_B3', 'V5_B5', 'V5_B7',
                 'V7_B1', 'V7_B3', 'V7_B5', 'V7_B7']

# List of file paths
file_paths = [
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b7.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b7.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b7.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b7.xlsx'
]

# Define color and line style mappings
color_map = {
    'V1': 'red',
    'V3': 'yellow',
    'V5': 'blue',
    'V7': 'orange'
}

line_style_map = {
    'B1': '-',  # Solid line
    'B3': '--', # Dashed line
    'B5': ':',  # Dotted line
    'B7': '-.'  # Dash-dot line
}

# Create a figure and axis
plt.figure(figsize=(12, 8))

# Loop through each file and plot the data
for file_path, window_frame in zip(file_paths, window_frames):
    # Extract V and B from the window_frame
    v_part = window_frame.split('_')[0]  # e.g., 'V1'
    b_part = window_frame.split('_')[1]  # e.g., 'B1'

    # Get the corresponding color and line style
    color = color_map[v_part]
    line_style = line_style_map[b_part]

    # Read the Excel file
    df = pd.read_excel(file_path)

    # Plot the threshold vs Recall with the corresponding color and line style
    plt.plot(df['Threshold'], df['F1 Score (Mecca)'], label=window_frame, color=color, linestyle=line_style)

# Add labels and title
plt.xlabel('Threshold')
plt.ylabel('Meccan F1 Score')
# plt.title('Threshold vs Precision for Different Window Frames')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')  # Place legend outside the plot

# Save the plot as a PNG file in Google Drive
save_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/threshold_vs_F1 Score (Mecca)_All.png'  # Specify your desired path in Google Drive
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

print(f"Plot saved to Google Drive at: {save_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Plot saved to Google Drive at: /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/threshold_vs_F1 Score (Mecca)_All.png

# %% [markdown]
# # **Precision (Medina)**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# List of window frames to evaluate
window_frames = ['V1_B1', 'V1_B3', 'V1_B5', 'V1_B7',
                 'V3_B1', 'V3_B3', 'V3_B5', 'V3_B7',
                 'V5_B1', 'V5_B3', 'V5_B5', 'V5_B7',
                 'V7_B1', 'V7_B3', 'V7_B5', 'V7_B7']

# List of file paths
file_paths = [
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b7.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b7.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b7.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b7.xlsx'
]

# Define color and line style mappings
color_map = {
    'V1': 'red',
    'V3': 'yellow',
    'V5': 'blue',
    'V7': 'orange'
}

line_style_map = {
    'B1': '-',  # Solid line
    'B3': '--', # Dashed line
    'B5': ':',  # Dotted line
    'B7': '-.'  # Dash-dot line
}

# Create a figure and axis
plt.figure(figsize=(12, 8))

# Loop through each file and plot the data
for file_path, window_frame in zip(file_paths, window_frames):
    # Extract V and B from the window_frame
    v_part = window_frame.split('_')[0]  # e.g., 'V1'
    b_part = window_frame.split('_')[1]  # e.g., 'B1'

    # Get the corresponding color and line style
    color = color_map[v_part]
    line_style = line_style_map[b_part]

    # Read the Excel file
    df = pd.read_excel(file_path)

    # Plot the threshold vs Precision with the corresponding color and line style
    plt.plot(df['Threshold'], df['Precision (Medina)'], label=window_frame, color=color, linestyle=line_style)

# Add labels and title
plt.xlabel('Threshold')
plt.ylabel('Median Precision')
# plt.title('Threshold vs Precision for Different Window Frames')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')  # Place legend outside the plot

# Save the plot as a PNG file in Google Drive
save_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/threshold_vs_Precision_(Medina)_All.png'  # Specify your desired path in Google Drive
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

print(f"Plot saved to Google Drive at: {save_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Plot saved to Google Drive at: /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/threshold_vs_Precision_(Medina)_All.png

# %% [markdown]
# # **Recall (Medina)**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# List of window frames to evaluate
window_frames = ['V1_B1', 'V1_B3', 'V1_B5', 'V1_B7',
                 'V3_B1', 'V3_B3', 'V3_B5', 'V3_B7',
                 'V5_B1', 'V5_B3', 'V5_B5', 'V5_B7',
                 'V7_B1', 'V7_B3', 'V7_B5', 'V7_B7']

# List of file paths
file_paths = [
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b7.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b7.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b7.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b7.xlsx'
]

# Define color and line style mappings
color_map = {
    'V1': 'red',
    'V3': 'yellow',
    'V5': 'blue',
    'V7': 'orange'
}

line_style_map = {
    'B1': '-',  # Solid line
    'B3': '--', # Dashed line
    'B5': ':',  # Dotted line
    'B7': '-.'  # Dash-dot line
}

# Create a figure and axis
plt.figure(figsize=(12, 8))

# Loop through each file and plot the data
for file_path, window_frame in zip(file_paths, window_frames):
    # Extract V and B from the window_frame
    v_part = window_frame.split('_')[0]  # e.g., 'V1'
    b_part = window_frame.split('_')[1]  # e.g., 'B1'

    # Get the corresponding color and line style
    color = color_map[v_part]
    line_style = line_style_map[b_part]

    # Read the Excel file
    df = pd.read_excel(file_path)

    # Plot the threshold vs Recall with the corresponding color and line style
    plt.plot(df['Threshold'], df['Recall (Medina)'], label=window_frame, color=color, linestyle=line_style)

# Add labels and title
plt.xlabel('Threshold')
plt.ylabel('Median Recall')
# plt.title('Threshold vs Precision for Different Window Frames')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')  # Place legend outside the plot

# Save the plot as a PNG file in Google Drive
save_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/threshold_vs_Recall_(Medina)_All.png'  # Specify your desired path in Google Drive
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

print(f"Plot saved to Google Drive at: {save_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Plot saved to Google Drive at: /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/threshold_vs_Recall_(Medina)_All.png

# %% [markdown]
# # **F1 Score (Medina)**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# List of window frames to evaluate
window_frames = ['V1_B1', 'V1_B3', 'V1_B5', 'V1_B7',
                 'V3_B1', 'V3_B3', 'V3_B5', 'V3_B7',
                 'V5_B1', 'V5_B3', 'V5_B5', 'V5_B7',
                 'V7_B1', 'V7_B3', 'V7_B5', 'V7_B7']

# List of file paths
file_paths = [
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b7.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b7.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b7.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b7.xlsx'
]

# Define color and line style mappings
color_map = {
    'V1': 'red',
    'V3': 'yellow',
    'V5': 'blue',
    'V7': 'orange'
}

line_style_map = {
    'B1': '-',  # Solid line
    'B3': '--', # Dashed line
    'B5': ':',  # Dotted line
    'B7': '-.'  # Dash-dot line
}

# Create a figure and axis
plt.figure(figsize=(12, 8))

# Loop through each file and plot the data
for file_path, window_frame in zip(file_paths, window_frames):
    # Extract V and B from the window_frame
    v_part = window_frame.split('_')[0]  # e.g., 'V1'
    b_part = window_frame.split('_')[1]  # e.g., 'B1'

    # Get the corresponding color and line style
    color = color_map[v_part]
    line_style = line_style_map[b_part]

    # Read the Excel file
    df = pd.read_excel(file_path)

    # Plot the threshold vs Recall with the corresponding color and line style
    plt.plot(df['Threshold'], df['F1 Score (Medina)'], label=window_frame, color=color, linestyle=line_style)

# Add labels and title
plt.xlabel('Threshold')
plt.ylabel('Median F1 Score')
# plt.title('Threshold vs Precision for Different Window Frames')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')  # Place legend outside the plot

# Save the plot as a PNG file in Google Drive
save_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/threshold_vs_F1 Score (Medina)_All.png'  # Specify your desired path in Google Drive
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

print(f"Plot saved to Google Drive at: {save_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Plot saved to Google Drive at: /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/threshold_vs_F1 Score (Medina)_All.png

# %% [markdown]
# # ***Scopes for proof***

# %%
import pandas as pd

# Load the Excel file
file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/D7.xlsx'  # Replace with the actual path to your file
df = pd.read_excel(file_path, sheet_name='Sheet1')  # Replace 'Sheet1' with the correct sheet name if needed

# Count the number of rows
num_rows = len(df)

print(f"Total number of rows in the Excel sheet: {num_rows}")
# Out:
# Total number of rows in the Excel sheet: 5258

# %%
import pandas as pd
import matplotlib.pyplot as plt

# List of file paths
file_paths = [
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/D1.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/D3.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/D5.xlsx',
    '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/D7.xlsx'
]

# Initialize a list to store the number of rows for each file
num_rows_list = []

# Iterate over each file path
for file_path in file_paths:
    # Load the Excel file
    df = pd.read_excel(file_path, sheet_name='Sheet1')  # Replace 'Sheet1' with the correct sheet name if needed

    # Count the number of rows
    num_rows = len(df)
    num_rows_list.append(num_rows)

    print(f"Total number of rows in {file_path}: {num_rows}")

# Plot the total number of rows for each file as a bar graph
plt.figure(figsize=(10, 6))
bars = plt.bar(range(len(file_paths)), num_rows_list, color=['skyblue', 'lightgreen', 'salmon', 'orange'], tick_label=[f'V{i}' for i in [1, 3, 5, 7]])

# Add data labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{int(height)}', ha='center', va='bottom', fontsize=12)

# Customize the graph
plt.title('Total Number of Frames in Each Window Frames', fontsize=16, fontweight='bold')
plt.xlabel('Window Frames', fontsize=14)
plt.ylabel('Scopes', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add grid lines for better readability

# Save the plot as a PNG file in Google Drive
save_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/Window_frames_scopes.png'  # Specify your desired path in Google Drive
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# Show the plot
plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

print(f"Plot saved to Google Drive at: {save_path}")
# Out:
# Total number of rows in /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/D1.xlsx: 5920
# Total number of rows in /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/D3.xlsx: 5692
# Total number of rows in /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/D5.xlsx: 5468
# Total number of rows in /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/D7.xlsx: 5258
# Plot saved to Google Drive at: /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/Window_frames_scopes.png

# %% [markdown]
# test

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel file
file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/v7 b3.xlsx'
df = pd.read_excel(file_path, sheet_name='Sheet1')

# Convert the 'Period Match' column to boolean values
df['Period Match'] = df['Period Match'].astype(bool)

# Count the number of matches and mismatches
match_counts = df['Period Match'].value_counts()

# Plot the data
plt.figure(figsize=(8, 6))
match_counts.plot(kind='bar', color=['green', 'red'])
plt.title('Period Match Analysis')
plt.xlabel('Match Status')
plt.ylabel('Count')
plt.xticks([0, 1], ['Match (True)', 'Mismatch (False)'], rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Excel file
file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/v7 b3.xlsx'
df = pd.read_excel(file_path, sheet_name='Sheet1')

# Check the data
print("First few rows of the dataset:")
print(df.head())

# Check the 'Period Match' column
print("\nUnique values in 'Period Match':")
print(df['Period Match'].unique())

# Convert the 'Period Match' column to boolean values
df['Period Match'] = df['Period Match'].astype(bool)

# Count the number of matches and mismatches
match_counts = df['Period Match'].value_counts()

# Check the match counts
print("\nMatch counts:")
print(match_counts)

# Custom colors and styling
colors = ['#4CAF50', '#FF5252']  # Green for True, Red for False
sns.set_style("whitegrid")  # Use seaborn's whitegrid style for a clean look

# Plot the data with vertical bars
plt.figure(figsize=(10, 6))
bars = plt.bar(['Match (True)', 'Mismatch (False)'], match_counts.values, color=colors, edgecolor='black', linewidth=1.5)

# Add annotations for each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height}',
             ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')

# Customize the plot
plt.title('Period Match Analysis', fontsize=18, fontweight='bold', pad=20, color='#333333')
plt.xlabel('Match Status', fontsize=14, fontweight='bold', labelpad=10, color='#333333')
plt.ylabel('Count', fontsize=14, fontweight='bold', labelpad=10, color='#333333')
plt.xticks(fontsize=12, fontweight='bold', color='#333333')
plt.yticks(fontsize=12, color='#333333')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Remove spines for a cleaner look
for spine in plt.gca().spines.values():
    spine.set_visible(False)

# Add a light background for better contrast
plt.gca().set_facecolor('#F5F5F5')

# Add a subtle shadow effect to the bars
for bar in bars:
    bar.set_edgecolor('#333333')
    bar.set_linewidth(1.5)
    bar.set_alpha(0.9)

# Add a horizontal line for better readability
plt.axhline(0, color='black', linewidth=1.5, alpha=0.7)

# Save the plot as a PNG file in Google Drive
save_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/Match_&_Mismatch_Period.png'  # Specify your desired path in Google Drive
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# Show the plot
plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

print(f"Plot saved to Google Drive at: {save_path}")
# Out:
# First few rows of the dataset:
#    Surah No Verse Range                            Verse (as Window Frame)  \
# 0         1         1-7  In the Name of Allah- the Most Compassionate, ...
# 1         2         1-7  Alif-Lam-Mim. This is the Book! There is no do...
# 2         2         2-8  This is the Book! There is no doubt about it w...
# 3         2         3-9  who believe in the unseen, establish prayer, a...
# 4         2        4-10  and who believe in what has been revealed to y...
#
#   Actual Period Predicted Period  \
# 0     undecided            Mecca
# 1        Medina            Mecca
# 2        Medina            Mecca
# 3        Medina           Medina
# 4        Medina            Mecca
#
#                                      Best Match Line  \
# 0  (I urge you to) believe in Allah and His Messe...
# 1  And even if We had sent down unto them angels,...
# 2  ” (Soorah Al-An‘am 6:109-111) Allah, Most High...
# 3  those who believe in it, accepts its reality w...
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Excel file
file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/v7 b3.xlsx'
df = pd.read_excel(file_path, sheet_name='Sheet1')

# Check the data
print("First few rows of the dataset:")
print(df.head())

# Filter rows where the actual period is undecided
undecided_df = df[df['Actual Period'] == 'undecided']

# Check the filtered data
print("\nRows where Actual Period is undecided:")
print(undecided_df.head())

# Count the occurrences of predicted periods (Mecca or Medina)
predicted_counts = undecided_df['Predicted Period'].value_counts()

# Check the predicted counts
print("\nPredicted Period counts for undecided Actual Period:")
print(predicted_counts)

# Custom colors and styling
colors = ['#1f77b4', '#ff7f0e']  # Blue for Mecca, Orange for Medina
sns.set_style("whitegrid")  # Use seaborn's whitegrid style for a clean look

# Plot the data with vertical bars
plt.figure(figsize=(10, 6))
bars = plt.bar(predicted_counts.index, predicted_counts.values, color=colors, edgecolor='black', linewidth=1.5)

# Add annotations for each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height}',
             ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')

# Customize the plot
plt.title('Predicted Period for Undecided Actual Period', fontsize=18, fontweight='bold', pad=20, color='#333333')
plt.xlabel('Predicted Period', fontsize=14, fontweight='bold', labelpad=10, color='#333333')
plt.ylabel('Count', fontsize=14, fontweight='bold', labelpad=10, color='#333333')
plt.xticks(fontsize=12, fontweight='bold', color='#333333')
plt.yticks(fontsize=12, color='#333333')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Remove spines for a cleaner look
for spine in plt.gca().spines.values():
    spine.set_visible(False)

# Add a light background for better contrast
plt.gca().set_facecolor('#F5F5F5')

# Add a subtle shadow effect to the bars
for bar in bars:
    bar.set_edgecolor('#333333')
    bar.set_linewidth(1.5)
    bar.set_alpha(0.9)

# Add a horizontal line for better readability
plt.axhline(0, color='black', linewidth=1.5, alpha=0.7)

# Save the plot as a PNG file in Google Drive
save_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/Undecided_predict.png'  # Specify your desired path in Google Drive
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# Show the plot
plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

print(f"Plot saved to Google Drive at: {save_path}")
# Out:
# First few rows of the dataset:
#    Surah No Verse Range                            Verse (as Window Frame)  \
# 0         1         1-7  In the Name of Allah- the Most Compassionate, ...
# 1         2         1-7  Alif-Lam-Mim. This is the Book! There is no do...
# 2         2         2-8  This is the Book! There is no doubt about it w...
# 3         2         3-9  who believe in the unseen, establish prayer, a...
# 4         2        4-10  and who believe in what has been revealed to y...
#
#   Actual Period Predicted Period  \
# 0     undecided            Mecca
# 1        Medina            Mecca
# 2        Medina            Mecca
# 3        Medina           Medina
# 4        Medina            Mecca
#
#                                      Best Match Line  \
# 0  (I urge you to) believe in Allah and His Messe...
# 1  And even if We had sent down unto them angels,...
# 2  ” (Soorah Al-An‘am 6:109-111) Allah, Most High...
# 3  those who believe in it, accepts its reality w...
# ...

# %% [markdown]
# # ***10 Graphs***

# %% [markdown]
# # **Accuracy**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# List of file paths for each version and window frame
file_paths = {
    'v1': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b7.xlsx'
    },
    'v3': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b7.xlsx'
    },
    'v5': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b7.xlsx'
    },
    'v7': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b7.xlsx'
    }
}

# Initialize a dictionary to store the best accuracy for each version and window frame
best_data = {'Version': [], 'Window Frame': [], 'Accuracy': []}

# Loop through each version and window frame to extract the best accuracy
for version, frames in file_paths.items():
    for frame, file_path in frames.items():
        df = pd.read_excel(file_path)
        best_accuracy = df['Accuracy'].max()  # Find the maximum accuracy
        best_data['Version'].append(version)
        best_data['Window Frame'].append(frame)
        best_data['Accuracy'].append(best_accuracy)

# Convert the dictionary to a DataFrame
best_df = pd.DataFrame(best_data)

# Define colors and line styles for each window frame
colors = {
    'B1': 'red',
    'B3': 'blue',
    'B5': 'green',
    'B7': 'orange'
}

line_styles = {
    'B1': '-',  # Solid line
    'B3': '--', # Dashed line
    'B5': ':',  # Dotted line
    'B7': '-.'  # Dash-dot line
}

# Create a figure and axis
plt.figure(figsize=(12, 8))

# Plot the line graph for each window frame
for frame in best_df['Window Frame'].unique():
    frame_data = best_df[best_df['Window Frame'] == frame]
    plt.plot(
        frame_data['Version'],  # X-axis: Version (v1, v3, v5, v7)
        frame_data['Accuracy'],  # Y-axis: Accuracy
        marker='o',  # Add markers
        linestyle=line_styles[frame],  # Line style
        color=colors[frame],  # Line color
        label=f'{frame}'  # Label for the legend
    )

# Add labels and title
plt.xlabel('Verse Ranges', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.title('Best Accuracy per Version for Different Window Frames', fontsize=16)

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)

# Add legend outside the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=12, title='Window Frame')

# Adjust layout to prevent clipping of labels
plt.tight_layout()

# Save the plot as a PNG file in Google Drive
save_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/best_accuracy_per_threshold_version_window_frames.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

print(f"Plot saved to Google Drive at: {save_path}")
# Out:
# Plot saved to Google Drive at: /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/best_accuracy_per_threshold_version_window_frames.png

# %% [markdown]
# # **Meccan Precision**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# List of file paths for each version and window frame
file_paths = {
    'v1': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b7.xlsx'
    },
    'v3': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b7.xlsx'
    },
    'v5': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b7.xlsx'
    },
    'v7': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b7.xlsx'
    }
}

# Initialize a dictionary to store the best Precision (Mecca) for each version and window frame
best_data = {'Version': [], 'Window Frame': [], 'Precision (Mecca)': []}

# Loop through each version and window frame to extract the best Precision (Mecca)
for version, frames in file_paths.items():
    for frame, file_path in frames.items():
        df = pd.read_excel(file_path)
        best_idx = df['Accuracy'].idxmax()  # Find the index of the maximum accuracy
        best_precision_mecca = df.loc[best_idx, 'Precision (Mecca)']  # Get Precision (Mecca) at that index
        best_data['Version'].append(version)
        best_data['Window Frame'].append(frame)
        best_data['Precision (Mecca)'].append(best_precision_mecca)

# Convert the dictionary to a DataFrame
best_df = pd.DataFrame(best_data)

# Define colors and line styles for each window frame
colors = {
    'B1': 'red',
    'B3': 'blue',
    'B5': 'green',
    'B7': 'orange'
}

line_styles = {
    'B1': '-',  # Solid line
    'B3': '--', # Dashed line
    'B5': ':',  # Dotted line
    'B7': '-.'  # Dash-dot line
}

# Create a figure and axis
plt.figure(figsize=(12, 8))

# Plot the line graph for each window frame
for frame in best_df['Window Frame'].unique():
    frame_data = best_df[best_df['Window Frame'] == frame]
    plt.plot(
        frame_data['Version'],  # X-axis: Version (v1, v3, v5, v7)
        frame_data['Precision (Mecca)'],  # Y-axis: Precision (Mecca)
        marker='o',  # Add markers
        linestyle=line_styles[frame],  # Line style
        color=colors[frame],  # Line color
        label=f'{frame}'  # Label for the legend
    )

# Add labels and title
plt.xlabel('Verse Ranges', fontsize=14)
plt.ylabel('Meccan Precision', fontsize=14)
plt.title('Meccan Precision at Best Accuracy Threshold per Version for Different Window Frames', fontsize=16)

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)

# Add legend outside the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=12, title='Window Frame')

# Adjust layout to prevent clipping of labels
plt.tight_layout()

# Save the plot as a PNG file in Google Drive
save_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/precision_mecca_best_accuracy_threshold.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

print(f"Plot saved to Google Drive at: {save_path}")
# Out:
# Plot saved to Google Drive at: /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/precision_mecca_best_accuracy_threshold.png

# %% [markdown]
# # **Meccan Recall**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# List of file paths for each version and window frame
file_paths = {
    'v1': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b7.xlsx'
    },
    'v3': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b7.xlsx'
    },
    'v5': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b7.xlsx'
    },
    'v7': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b7.xlsx'
    }
}

# Initialize a dictionary to store the best Recall (Mecca) for each version and window frame
best_data = {'Version': [], 'Window Frame': [], 'Recall (Mecca)': []}

# Loop through each version and window frame to extract the best Recall (Mecca)
for version, frames in file_paths.items():
    for frame, file_path in frames.items():
        df = pd.read_excel(file_path)
        best_idx = df['Accuracy'].idxmax()  # Find the index of the maximum accuracy
        best_Recall_mecca = df.loc[best_idx, 'Recall (Mecca)']  # Get Recall (Mecca) at that index
        best_data['Version'].append(version)
        best_data['Window Frame'].append(frame)
        best_data['Recall (Mecca)'].append(best_Recall_mecca)

# Convert the dictionary to a DataFrame
best_df = pd.DataFrame(best_data)

# Define colors and line styles for each window frame
colors = {
    'B1': 'red',
    'B3': 'blue',
    'B5': 'green',
    'B7': 'orange'
}

line_styles = {
    'B1': '-',  # Solid line
    'B3': '--', # Dashed line
    'B5': ':',  # Dotted line
    'B7': '-.'  # Dash-dot line
}

# Create a figure and axis
plt.figure(figsize=(12, 8))

# Plot the line graph for each window frame
for frame in best_df['Window Frame'].unique():
    frame_data = best_df[best_df['Window Frame'] == frame]
    plt.plot(
        frame_data['Version'],  # X-axis: Version (v1, v3, v5, v7)
        frame_data['Recall (Mecca)'],  # Y-axis: Recall (Mecca)
        marker='o',  # Add markers
        linestyle=line_styles[frame],  # Line style
        color=colors[frame],  # Line color
        label=f'{frame}'  # Label for the legend
    )

# Add labels and title
plt.xlabel('Verse Ranges', fontsize=14)
plt.ylabel('Meccan Recall', fontsize=14)
plt.title('Meccan Recall at Best Accuracy Threshold per Version for Different Window Frames', fontsize=16)

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)

# Add legend outside the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=12, title='Window Frame')

# Adjust layout to prevent clipping of labels
plt.tight_layout()

# Save the plot as a PNG file in Google Drive
save_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/Recall_mecca_best_accuracy_threshold.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

print(f"Plot saved to Google Drive at: {save_path}")
# Out:
# Plot saved to Google Drive at: /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/Recall_mecca_best_accuracy_threshold.png

# %% [markdown]
# # **Meccan F1 Score**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# List of file paths for each version and window frame
file_paths = {
    'v1': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b7.xlsx'
    },
    'v3': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b7.xlsx'
    },
    'v5': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b7.xlsx'
    },
    'v7': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b7.xlsx'
    }
}

# Initialize a dictionary to store the best F1 Score (Mecca) for each version and window frame
best_data = {'Version': [], 'Window Frame': [], 'F1 Score (Mecca)': []}

# Loop through each version and window frame to extract the best F1 Score (Mecca)
for version, frames in file_paths.items():
    for frame, file_path in frames.items():
        df = pd.read_excel(file_path)
        best_idx = df['Accuracy'].idxmax()  # Find the index of the maximum accuracy
        best_F1_Score_mecca = df.loc[best_idx, 'F1 Score (Mecca)']  # Get F1 Score (Mecca) at that index
        best_data['Version'].append(version)
        best_data['Window Frame'].append(frame)
        best_data['F1 Score (Mecca)'].append(best_F1_Score_mecca)

# Convert the dictionary to a DataFrame
best_df = pd.DataFrame(best_data)

# Define colors and line styles for each window frame
colors = {
    'B1': 'red',
    'B3': 'blue',
    'B5': 'green',
    'B7': 'orange'
}

line_styles = {
    'B1': '-',  # Solid line
    'B3': '--', # Dashed line
    'B5': ':',  # Dotted line
    'B7': '-.'  # Dash-dot line
}

# Create a figure and axis
plt.figure(figsize=(12, 8))

# Plot the line graph for each window frame
for frame in best_df['Window Frame'].unique():
    frame_data = best_df[best_df['Window Frame'] == frame]
    plt.plot(
        frame_data['Version'],  # X-axis: Version (v1, v3, v5, v7)
        frame_data['F1 Score (Mecca)'],  # Y-axis: F1 Score (Mecca)
        marker='o',  # Add markers
        linestyle=line_styles[frame],  # Line style
        color=colors[frame],  # Line color
        label=f'{frame}'  # Label for the legend
    )

# Add labels and title
plt.xlabel('Verse Ranges', fontsize=14)
plt.ylabel('Meccan F1 Score', fontsize=14)
plt.title('Meccan F1 Score at Best Accuracy Threshold per Version for Different Window Frames', fontsize=16)

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)

# Add legend outside the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=12, title='Window Frame')

# Adjust layout to prevent clipping of labels
plt.tight_layout()

# Save the plot as a PNG file in Google Drive
save_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/F1 Score_mecca_best_accuracy_threshold.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

print(f"Plot saved to Google Drive at: {save_path}")
# Out:
# Plot saved to Google Drive at: /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/F1 Score_mecca_best_accuracy_threshold.png

# %% [markdown]
# # **Median Precision**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# List of file paths for each version and window frame
file_paths = {
    'v1': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b7.xlsx'
    },
    'v3': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b7.xlsx'
    },
    'v5': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b7.xlsx'
    },
    'v7': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b7.xlsx'
    }
}

# Initialize a dictionary to store the best Precision (Medina) for each version and window frame
best_data = {'Version': [], 'Window Frame': [], 'Precision (Medina)': []}

# Loop through each version and window frame to extract the best Precision (Medina)
for version, frames in file_paths.items():
    for frame, file_path in frames.items():
        df = pd.read_excel(file_path)
        best_idx = df['Accuracy'].idxmax()  # Find the index of the maximum accuracy
        best_precision_Medina = df.loc[best_idx, 'Precision (Medina)']  # Get Precision (Medina) at that index
        best_data['Version'].append(version)
        best_data['Window Frame'].append(frame)
        best_data['Precision (Medina)'].append(best_precision_Medina)

# Convert the dictionary to a DataFrame
best_df = pd.DataFrame(best_data)

# Define colors and line styles for each window frame
colors = {
    'B1': 'red',
    'B3': 'blue',
    'B5': 'green',
    'B7': 'orange'
}

line_styles = {
    'B1': '-',  # Solid line
    'B3': '--', # Dashed line
    'B5': ':',  # Dotted line
    'B7': '-.'  # Dash-dot line
}

# Create a figure and axis
plt.figure(figsize=(12, 8))

# Plot the line graph for each window frame
for frame in best_df['Window Frame'].unique():
    frame_data = best_df[best_df['Window Frame'] == frame]
    plt.plot(
        frame_data['Version'],  # X-axis: Version (v1, v3, v5, v7)
        frame_data['Precision (Medina)'],  # Y-axis: Precision (Medina)
        marker='o',  # Add markers
        linestyle=line_styles[frame],  # Line style
        color=colors[frame],  # Line color
        label=f'{frame}'  # Label for the legend
    )

# Add labels and title
plt.xlabel('Verse Ranges', fontsize=14)
plt.ylabel('Median Precision', fontsize=14)
plt.title('Median Precision at Best Accuracy Threshold per Version for Different Window Frames', fontsize=16)

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)

# Add legend outside the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=12, title='Window Frame')

# Adjust layout to prevent clipping of labels
plt.tight_layout()

# Save the plot as a PNG file in Google Drive
save_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/precision_Medina_best_accuracy_threshold.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

print(f"Plot saved to Google Drive at: {save_path}")
# Out:
# Plot saved to Google Drive at: /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/precision_Medina_best_accuracy_threshold.png

# %% [markdown]
# # **Median Recall**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# List of file paths for each version and window frame
file_paths = {
    'v1': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b7.xlsx'
    },
    'v3': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b7.xlsx'
    },
    'v5': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b7.xlsx'
    },
    'v7': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b7.xlsx'
    }
}

# Initialize a dictionary to store the best Recall (Medina) for each version and window frame
best_data = {'Version': [], 'Window Frame': [], 'Recall (Medina)': []}

# Loop through each version and window frame to extract the best Recall (Medina)
for version, frames in file_paths.items():
    for frame, file_path in frames.items():
        df = pd.read_excel(file_path)
        best_idx = df['Accuracy'].idxmax()  # Find the index of the maximum accuracy
        best_Recall_Medina = df.loc[best_idx, 'Recall (Medina)']  # Get Recall (Medina) at that index
        best_data['Version'].append(version)
        best_data['Window Frame'].append(frame)
        best_data['Recall (Medina)'].append(best_Recall_Medina)

# Convert the dictionary to a DataFrame
best_df = pd.DataFrame(best_data)

# Define colors and line styles for each window frame
colors = {
    'B1': 'red',
    'B3': 'blue',
    'B5': 'green',
    'B7': 'orange'
}

line_styles = {
    'B1': '-',  # Solid line
    'B3': '--', # Dashed line
    'B5': ':',  # Dotted line
    'B7': '-.'  # Dash-dot line
}

# Create a figure and axis
plt.figure(figsize=(12, 8))

# Plot the line graph for each window frame
for frame in best_df['Window Frame'].unique():
    frame_data = best_df[best_df['Window Frame'] == frame]
    plt.plot(
        frame_data['Version'],  # X-axis: Version (v1, v3, v5, v7)
        frame_data['Recall (Medina)'],  # Y-axis: Recall (Medina)
        marker='o',  # Add markers
        linestyle=line_styles[frame],  # Line style
        color=colors[frame],  # Line color
        label=f'{frame}'  # Label for the legend
    )

# Add labels and title
plt.xlabel('Verse Ranges', fontsize=14)
plt.ylabel('Median Recall', fontsize=14)
plt.title('Median Recall at Best Accuracy Threshold per Version for Different Window Frames', fontsize=16)

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)

# Add legend outside the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=12, title='Window Frame')

# Adjust layout to prevent clipping of labels
plt.tight_layout()

# Save the plot as a PNG file in Google Drive
save_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/Recall_Medina_best_accuracy_threshold.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

print(f"Plot saved to Google Drive at: {save_path}")
# Out:
# Plot saved to Google Drive at: /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/Recall_Medina_best_accuracy_threshold.png

# %% [markdown]
# # **Median F1 Score**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# List of file paths for each version and window frame
file_paths = {
    'v1': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v1 b7.xlsx'
    },
    'v3': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v3 b7.xlsx'
    },
    'v5': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v5 b7.xlsx'
    },
    'v7': {
        'B1': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b1.xlsx',
        'B3': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b3.xlsx',
        'B5': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b5.xlsx',
        'B7': '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/O_v7 b7.xlsx'
    }
}

# Initialize a dictionary to store the best F1 Score (Medina) for each version and window frame
best_data = {'Version': [], 'Window Frame': [], 'F1 Score (Medina)': []}

# Loop through each version and window frame to extract the best F1 Score (Medina)
for version, frames in file_paths.items():
    for frame, file_path in frames.items():
        df = pd.read_excel(file_path)
        best_idx = df['Accuracy'].idxmax()  # Find the index of the maximum accuracy
        best_F1_Score_Medina = df.loc[best_idx, 'F1 Score (Medina)']  # Get F1 Score (Medina) at that index
        best_data['Version'].append(version)
        best_data['Window Frame'].append(frame)
        best_data['F1 Score (Medina)'].append(best_F1_Score_Medina)

# Convert the dictionary to a DataFrame
best_df = pd.DataFrame(best_data)

# Define colors and line styles for each window frame
colors = {
    'B1': 'red',
    'B3': 'blue',
    'B5': 'green',
    'B7': 'orange'
}

line_styles = {
    'B1': '-',  # Solid line
    'B3': '--', # Dashed line
    'B5': ':',  # Dotted line
    'B7': '-.'  # Dash-dot line
}

# Create a figure and axis
plt.figure(figsize=(12, 8))

# Plot the line graph for each window frame
for frame in best_df['Window Frame'].unique():
    frame_data = best_df[best_df['Window Frame'] == frame]
    plt.plot(
        frame_data['Version'],  # X-axis: Version (v1, v3, v5, v7)
        frame_data['F1 Score (Medina)'],  # Y-axis: F1 Score (Medina)
        marker='o',  # Add markers
        linestyle=line_styles[frame],  # Line style
        color=colors[frame],  # Line color
        label=f'{frame}'  # Label for the legend
    )

# Add labels and title
plt.xlabel('Verse Ranges', fontsize=14)
plt.ylabel('Median F1 Score', fontsize=14)
plt.title('Median F1 Score at Best Accuracy Threshold per Version for Different Window Frames', fontsize=16)

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)

# Add legend outside the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=12, title='Window Frame')

# Adjust layout to prevent clipping of labels
plt.tight_layout()

# Save the plot as a PNG file in Google Drive
save_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/F1 Score_Medina_best_accuracy_threshold.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

print(f"Plot saved to Google Drive at: {save_path}")
# Out:
# Plot saved to Google Drive at: /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_all-mpnet-base-v2/Graphs/F1 Score_Medina_best_accuracy_threshold.png

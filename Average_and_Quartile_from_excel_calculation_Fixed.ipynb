# %% [markdown]
# <a href="https://colab.research.google.com/github/zihan07/Research-of-Semantic-similarity-between-Quran-verses-with-Biographies/blob/Final-Code-of-the-Research/Average_and_Quartile_from_excel_calculation_Fixed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install pandas numpy openpyxl matplotlib

# %% [markdown]
# # **11**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from openpyxl import Workbook
from openpyxl.drawing.image import Image

# Load the Excel file
file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/v1 b1.xlsx'  # Replace with your file path
#sheet_name = 'v3 b5'  # Replace with your sheet name
df = pd.read_excel(file_path)

# Assuming the data is in column 'Best Match Score (as percentage)'
# Replace 'Best Match Score (as percentage)' with the actual column name if different
data_column = 'Best Match Score (as percentage)'

# Calculate quartiles and average
Q1 = np.percentile(df[data_column], 25)
Q2 = np.percentile(df[data_column], 50)  # Median
Q3 = np.percentile(df[data_column], 75)
average = np.mean(df[data_column])

# Print the results
print(f"1st Quartile (Q1): {Q1}")
print(f"2nd Quartile (Q2, Median): {Q2}")
print(f"3rd Quartile (Q3): {Q3}")
print(f"Average: {average}")

# Plot the data
plt.figure(figsize=(10, 6))
plt.boxplot(df[data_column], vert=False)
plt.title('Box Plot of Best Match Scores')
plt.xlabel('Best Match Score (as percentage)')
plt.savefig('boxplot.png')  # Save the plot as an image

# Create a new Excel file and save the chart
output_file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v1 b1.xlsx'
wb = Workbook()
ws = wb.active

# Add the quartiles and average to the Excel file
ws['A1'] = 'Quartile'
ws['B1'] = 'Threshold Value'
ws['A2'] = '1st Quartile (Q1)'
ws['B2'] = Q1
ws['A3'] = '2nd Quartile (Q2, Median)'
ws['B3'] = Q2
ws['A4'] = '3rd Quartile (Q3)'
ws['B4'] = Q3
ws['A5'] = 'Average'
ws['B5'] = average

# Add the chart image to the Excel file
img = Image('boxplot.png')
ws.add_image(img, 'D1')

# Save the Excel file
wb.save(output_file_path)

print(f"Chart and data saved to {output_file_path}")
# Out:
# 1st Quartile (Q1): 90.955
# 2nd Quartile (Q2, Median): 93.01
# 3rd Quartile (Q3): 94.35
# Average: 92.34841696232472
# Chart and data saved to /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v1 b1.xlsx

# %% [markdown]
# # **13**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from openpyxl import Workbook
from openpyxl.drawing.image import Image

# Load the Excel file
file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/v1 b3.xlsx'  # Replace with your file path
#sheet_name = 'v3 b5'  # Replace with your sheet name
df = pd.read_excel(file_path)

# Assuming the data is in column 'Best Match Score (as percentage)'
# Replace 'Best Match Score (as percentage)' with the actual column name if different
data_column = 'Best Match Score (as percentage)'

# Calculate quartiles and average
Q1 = np.percentile(df[data_column], 25)
Q2 = np.percentile(df[data_column], 50)  # Median
Q3 = np.percentile(df[data_column], 75)
average = np.mean(df[data_column])

# Print the results
print(f"1st Quartile (Q1): {Q1}")
print(f"2nd Quartile (Q2, Median): {Q2}")
print(f"3rd Quartile (Q3): {Q3}")
print(f"Average: {average}")

# Plot the data
plt.figure(figsize=(10, 6))
plt.boxplot(df[data_column], vert=False)
plt.title('Box Plot of Best Match Scores')
plt.xlabel('Best Match Score (as percentage)')
plt.savefig('boxplot.png')  # Save the plot as an image

# Create a new Excel file and save the chart
output_file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v1 b3.xlsx'
wb = Workbook()
ws = wb.active

# Add the quartiles and average to the Excel file
ws['A1'] = 'Quartile'
ws['B1'] = 'Threshold Value'
ws['A2'] = '1st Quartile (Q1)'
ws['B2'] = Q1
ws['A3'] = '2nd Quartile (Q2, Median)'
ws['B3'] = Q2
ws['A4'] = '3rd Quartile (Q3)'
ws['B4'] = Q3
ws['A5'] = 'Average'
ws['B5'] = average

# Add the chart image to the Excel file
img = Image('boxplot.png')
ws.add_image(img, 'D1')

# Save the Excel file
wb.save(output_file_path)

print(f"Chart and data saved to {output_file_path}")
# Out:
# 1st Quartile (Q1): 90.14500000000001
# 2nd Quartile (Q2, Median): 93.05
# 3rd Quartile (Q3): 94.68
# Average: 91.95082446359183
# Chart and data saved to /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v1 b3.xlsx

# %% [markdown]
# # **15**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from openpyxl import Workbook
from openpyxl.drawing.image import Image

# Load the Excel file
file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/v1 b5.xlsx'  # Replace with your file path
#sheet_name = 'v3 b5'  # Replace with your sheet name
df = pd.read_excel(file_path)

# Assuming the data is in column 'Best Match Score (as percentage)'
# Replace 'Best Match Score (as percentage)' with the actual column name if different
data_column = 'Best Match Score (as percentage)'

# Calculate quartiles and average
Q1 = np.percentile(df[data_column], 25)
Q2 = np.percentile(df[data_column], 50)  # Median
Q3 = np.percentile(df[data_column], 75)
average = np.mean(df[data_column])

# Print the results
print(f"1st Quartile (Q1): {Q1}")
print(f"2nd Quartile (Q2, Median): {Q2}")
print(f"3rd Quartile (Q3): {Q3}")
print(f"Average: {average}")

# Plot the data
plt.figure(figsize=(10, 6))
plt.boxplot(df[data_column], vert=False)
plt.title('Box Plot of Best Match Scores')
plt.xlabel('Best Match Score (as percentage)')
plt.savefig('boxplot.png')  # Save the plot as an image

# Create a new Excel file and save the chart
output_file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v1 b5.xlsx'
wb = Workbook()
ws = wb.active

# Add the quartiles and average to the Excel file
ws['A1'] = 'Quartile'
ws['B1'] = 'Threshold Value'
ws['A2'] = '1st Quartile (Q1)'
ws['B2'] = Q1
ws['A3'] = '2nd Quartile (Q2, Median)'
ws['B3'] = Q2
ws['A4'] = '3rd Quartile (Q3)'
ws['B4'] = Q3
ws['A5'] = 'Average'
ws['B5'] = average

# Add the chart image to the Excel file
img = Image('boxplot.png')
ws.add_image(img, 'D1')

# Save the Excel file
wb.save(output_file_path)

print(f"Chart and data saved to {output_file_path}")
# Out:
# 1st Quartile (Q1): 89.11
# 2nd Quartile (Q2, Median): 92.52
# 3rd Quartile (Q3): 94.42
# Average: 91.21035985808412
# Chart and data saved to /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v1 b5.xlsx

# %% [markdown]
# ## **17**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from openpyxl import Workbook
from openpyxl.drawing.image import Image

# Load the Excel file
file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/v1 b7.xlsx'  # Replace with your file path
#sheet_name = 'v3 b5'  # Replace with your sheet name
df = pd.read_excel(file_path)

# Assuming the data is in column 'Best Match Score (as percentage)'
# Replace 'Best Match Score (as percentage)' with the actual column name if different
data_column = 'Best Match Score (as percentage)'

# Calculate quartiles and average
Q1 = np.percentile(df[data_column], 25)
Q2 = np.percentile(df[data_column], 50)  # Median
Q3 = np.percentile(df[data_column], 75)
average = np.mean(df[data_column])

# Print the results
print(f"1st Quartile (Q1): {Q1}")
print(f"2nd Quartile (Q2, Median): {Q2}")
print(f"3rd Quartile (Q3): {Q3}")
print(f"Average: {average}")

# Plot the data
plt.figure(figsize=(10, 6))
plt.boxplot(df[data_column], vert=False)
plt.title('Box Plot of Best Match Scores')
plt.xlabel('Best Match Score (as percentage)')
plt.savefig('boxplot.png')  # Save the plot as an image

# Create a new Excel file and save the chart
output_file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v1 b7.xlsx'
wb = Workbook()
ws = wb.active

# Add the quartiles and average to the Excel file
ws['A1'] = 'Quartile'
ws['B1'] = 'Threshold Value'
ws['A2'] = '1st Quartile (Q1)'
ws['B2'] = Q1
ws['A3'] = '2nd Quartile (Q2, Median)'
ws['B3'] = Q2
ws['A4'] = '3rd Quartile (Q3)'
ws['B4'] = Q3
ws['A5'] = 'Average'
ws['B5'] = average

# Add the chart image to the Excel file
img = Image('boxplot.png')
ws.add_image(img, 'D1')

# Save the Excel file
wb.save(output_file_path)

print(f"Chart and data saved to {output_file_path}")
# Out:
# 1st Quartile (Q1): 88.185
# 2nd Quartile (Q2, Median): 91.93
# 3rd Quartile (Q3): 94.055
# Average: 90.51240750126709
# Chart and data saved to /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v1 b7.xlsx

# %% [markdown]
# # **31**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from openpyxl import Workbook
from openpyxl.drawing.image import Image

# Load the Excel file
file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/v3 b1.xlsx'  # Replace with your file path
#sheet_name = 'v3 b5'  # Replace with your sheet name
df = pd.read_excel(file_path)

# Assuming the data is in column 'Best Match Score (as percentage)'
# Replace 'Best Match Score (as percentage)' with the actual column name if different
data_column = 'Best Match Score (as percentage)'

# Calculate quartiles and average
Q1 = np.percentile(df[data_column], 25)
Q2 = np.percentile(df[data_column], 50)  # Median
Q3 = np.percentile(df[data_column], 75)
average = np.mean(df[data_column])

# Print the results
print(f"1st Quartile (Q1): {Q1}")
print(f"2nd Quartile (Q2, Median): {Q2}")
print(f"3rd Quartile (Q3): {Q3}")
print(f"Average: {average}")

# Plot the data
plt.figure(figsize=(10, 6))
plt.boxplot(df[data_column], vert=False)
plt.title('Box Plot of Best Match Scores')
plt.xlabel('Best Match Score (as percentage)')
plt.savefig('boxplot.png')  # Save the plot as an image

# Create a new Excel file and save the chart
output_file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v3 b1.xlsx'
wb = Workbook()
ws = wb.active

# Add the quartiles and average to the Excel file
ws['A1'] = 'Quartile'
ws['B1'] = 'Threshold Value'
ws['A2'] = '1st Quartile (Q1)'
ws['B2'] = Q1
ws['A3'] = '2nd Quartile (Q2, Median)'
ws['B3'] = Q2
ws['A4'] = '3rd Quartile (Q3)'
ws['B4'] = Q3
ws['A5'] = 'Average'
ws['B5'] = average

# Add the chart image to the Excel file
img = Image('boxplot.png')
ws.add_image(img, 'D1')

# Save the Excel file
wb.save(output_file_path)

print(f"Chart and data saved to {output_file_path}")
# Out:
# 1st Quartile (Q1): 94.23
# 2nd Quartile (Q2, Median): 95.29
# 3rd Quartile (Q3): 95.87
# Average: 94.85946767392832
# Chart and data saved to /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v3 b1.xlsx

# %% [markdown]
# # **33**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from openpyxl import Workbook
from openpyxl.drawing.image import Image

# Load the Excel file
file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/v3 b3.xlsx'  # Replace with your file path
#sheet_name = 'v3 b5'  # Replace with your sheet name
df = pd.read_excel(file_path)

# Assuming the data is in column 'Best Match Score (as percentage)'
# Replace 'Best Match Score (as percentage)' with the actual column name if different
data_column = 'Best Match Score (as percentage)'

# Calculate quartiles and average
Q1 = np.percentile(df[data_column], 25)
Q2 = np.percentile(df[data_column], 50)  # Median
Q3 = np.percentile(df[data_column], 75)
average = np.mean(df[data_column])

# Print the results
print(f"1st Quartile (Q1): {Q1}")
print(f"2nd Quartile (Q2, Median): {Q2}")
print(f"3rd Quartile (Q3): {Q3}")
print(f"Average: {average}")

# Plot the data
plt.figure(figsize=(10, 6))
plt.boxplot(df[data_column], vert=False)
plt.title('Box Plot of Best Match Scores')
plt.xlabel('Best Match Score (as percentage)')
plt.savefig('boxplot.png')  # Save the plot as an image

# Create a new Excel file and save the chart
output_file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v3 b3.xlsx'
wb = Workbook()
ws = wb.active

# Add the quartiles and average to the Excel file
ws['A1'] = 'Quartile'
ws['B1'] = 'Threshold Value'
ws['A2'] = '1st Quartile (Q1)'
ws['B2'] = Q1
ws['A3'] = '2nd Quartile (Q2, Median)'
ws['B3'] = Q2
ws['A4'] = '3rd Quartile (Q3)'
ws['B4'] = Q3
ws['A5'] = 'Average'
ws['B5'] = average

# Add the chart image to the Excel file
img = Image('boxplot.png')
ws.add_image(img, 'D1')

# Save the Excel file
wb.save(output_file_path)

print(f"Chart and data saved to {output_file_path}")
# Out:
# 1st Quartile (Q1): 94.89750000000001
# 2nd Quartile (Q2, Median): 96.06
# 3rd Quartile (Q3): 96.71
# Average: 95.54412157413917
# Chart and data saved to /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v3 b3.xlsx

# %% [markdown]
# # **35**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from openpyxl import Workbook
from openpyxl.drawing.image import Image

# Load the Excel file
file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/v3 b5.xlsx'  # Replace with your file path
#sheet_name = 'v3 b5'  # Replace with your sheet name
df = pd.read_excel(file_path)

# Assuming the data is in column 'Best Match Score (as percentage)'
# Replace 'Best Match Score (as percentage)' with the actual column name if different
data_column = 'Best Match Score (as percentage)'

# Calculate quartiles and average
Q1 = np.percentile(df[data_column], 25)
Q2 = np.percentile(df[data_column], 50)  # Median
Q3 = np.percentile(df[data_column], 75)
average = np.mean(df[data_column])

# Print the results
print(f"1st Quartile (Q1): {Q1}")
print(f"2nd Quartile (Q2, Median): {Q2}")
print(f"3rd Quartile (Q3): {Q3}")
print(f"Average: {average}")

# Plot the data
plt.figure(figsize=(10, 6))
plt.boxplot(df[data_column], vert=False)
plt.title('Box Plot of Best Match Scores')
plt.xlabel('Best Match Score (as percentage)')
plt.savefig('boxplot.png')  # Save the plot as an image

# Create a new Excel file and save the chart
output_file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v3 b5.xlsx'
wb = Workbook()
ws = wb.active

# Add the quartiles and average to the Excel file
ws['A1'] = 'Quartile'
ws['B1'] = 'Threshold Value'
ws['A2'] = '1st Quartile (Q1)'
ws['B2'] = Q1
ws['A3'] = '2nd Quartile (Q2, Median)'
ws['B3'] = Q2
ws['A4'] = '3rd Quartile (Q3)'
ws['B4'] = Q3
ws['A5'] = 'Average'
ws['B5'] = average

# Add the chart image to the Excel file
img = Image('boxplot.png')
ws.add_image(img, 'D1')

# Save the Excel file
wb.save(output_file_path)

print(f"Chart and data saved to {output_file_path}")
# Out:
# 1st Quartile (Q1): 94.64
# 2nd Quartile (Q2, Median): 96.06
# 3rd Quartile (Q3): 96.8
# Average: 95.46579058327478
# Chart and data saved to /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v3 b5.xlsx

# %% [markdown]
# # **37**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from openpyxl import Workbook
from openpyxl.drawing.image import Image

# Load the Excel file
file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/v3 b7.xlsx'  # Replace with your file path
#sheet_name = 'v3 b5'  # Replace with your sheet name
df = pd.read_excel(file_path)

# Assuming the data is in column 'Best Match Score (as percentage)'
# Replace 'Best Match Score (as percentage)' with the actual column name if different
data_column = 'Best Match Score (as percentage)'

# Calculate quartiles and average
Q1 = np.percentile(df[data_column], 25)
Q2 = np.percentile(df[data_column], 50)  # Median
Q3 = np.percentile(df[data_column], 75)
average = np.mean(df[data_column])

# Print the results
print(f"1st Quartile (Q1): {Q1}")
print(f"2nd Quartile (Q2, Median): {Q2}")
print(f"3rd Quartile (Q3): {Q3}")
print(f"Average: {average}")

# Plot the data
plt.figure(figsize=(10, 6))
plt.boxplot(df[data_column], vert=False)
plt.title('Box Plot of Best Match Scores')
plt.xlabel('Best Match Score (as percentage)')
plt.savefig('boxplot.png')  # Save the plot as an image

# Create a new Excel file and save the chart
output_file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v3 b7.xlsx'
wb = Workbook()
ws = wb.active

# Add the quartiles and average to the Excel file
ws['A1'] = 'Quartile'
ws['B1'] = 'Threshold Value'
ws['A2'] = '1st Quartile (Q1)'
ws['B2'] = Q1
ws['A3'] = '2nd Quartile (Q2, Median)'
ws['B3'] = Q2
ws['A4'] = '3rd Quartile (Q3)'
ws['B4'] = Q3
ws['A5'] = 'Average'
ws['B5'] = average

# Add the chart image to the Excel file
img = Image('boxplot.png')
ws.add_image(img, 'D1')

# Save the Excel file
wb.save(output_file_path)

print(f"Chart and data saved to {output_file_path}")
# Out:
# 1st Quartile (Q1): 94.29
# 2nd Quartile (Q2, Median): 95.94
# 3rd Quartile (Q3): 96.75
# Average: 95.24640196767393
# Chart and data saved to /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v3 b7.xlsx

# %% [markdown]
# # **51**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from openpyxl import Workbook
from openpyxl.drawing.image import Image

# Load the Excel file
file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/v5 b1.xlsx'  # Replace with your file path
#sheet_name = 'v3 b5'  # Replace with your sheet name
df = pd.read_excel(file_path)

# Assuming the data is in column 'Best Match Score (as percentage)'
# Replace 'Best Match Score (as percentage)' with the actual column name if different
data_column = 'Best Match Score (as percentage)'

# Calculate quartiles and average
Q1 = np.percentile(df[data_column], 25)
Q2 = np.percentile(df[data_column], 50)  # Median
Q3 = np.percentile(df[data_column], 75)
average = np.mean(df[data_column])

# Print the results
print(f"1st Quartile (Q1): {Q1}")
print(f"2nd Quartile (Q2, Median): {Q2}")
print(f"3rd Quartile (Q3): {Q3}")
print(f"Average: {average}")

# Plot the data
plt.figure(figsize=(10, 6))
plt.boxplot(df[data_column], vert=False)
plt.title('Box Plot of Best Match Scores')
plt.xlabel('Best Match Score (as percentage)')
plt.savefig('boxplot.png')  # Save the plot as an image

# Create a new Excel file and save the chart
output_file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v5 b1.xlsx'
wb = Workbook()
ws = wb.active

# Add the quartiles and average to the Excel file
ws['A1'] = 'Quartile'
ws['B1'] = 'Threshold Value'
ws['A2'] = '1st Quartile (Q1)'
ws['B2'] = Q1
ws['A3'] = '2nd Quartile (Q2, Median)'
ws['B3'] = Q2
ws['A4'] = '3rd Quartile (Q3)'
ws['B4'] = Q3
ws['A5'] = 'Average'
ws['B5'] = average

# Add the chart image to the Excel file
img = Image('boxplot.png')
ws.add_image(img, 'D1')

# Save the Excel file
wb.save(output_file_path)

print(f"Chart and data saved to {output_file_path}")
# Out:
# 1st Quartile (Q1): 95.03
# 2nd Quartile (Q2, Median): 95.68
# 3rd Quartile (Q3): 96.12
# Average: 95.4223756400878
# Chart and data saved to /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v5 b1.xlsx

# %% [markdown]
# # **53**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from openpyxl import Workbook
from openpyxl.drawing.image import Image

# Load the Excel file
file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/v5 b3.xlsx'  # Replace with your file path
#sheet_name = 'v3 b5'  # Replace with your sheet name
df = pd.read_excel(file_path)

# Assuming the data is in column 'Best Match Score (as percentage)'
# Replace 'Best Match Score (as percentage)' with the actual column name if different
data_column = 'Best Match Score (as percentage)'

# Calculate quartiles and average
Q1 = np.percentile(df[data_column], 25)
Q2 = np.percentile(df[data_column], 50)  # Median
Q3 = np.percentile(df[data_column], 75)
average = np.mean(df[data_column])

# Print the results
print(f"1st Quartile (Q1): {Q1}")
print(f"2nd Quartile (Q2, Median): {Q2}")
print(f"3rd Quartile (Q3): {Q3}")
print(f"Average: {average}")

# Plot the data
plt.figure(figsize=(10, 6))
plt.boxplot(df[data_column], vert=False)
plt.title('Box Plot of Best Match Scores')
plt.xlabel('Best Match Score (as percentage)')
plt.savefig('boxplot.png')  # Save the plot as an image

# Create a new Excel file and save the chart
output_file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v5 b3.xlsx'
wb = Workbook()
ws = wb.active

# Add the quartiles and average to the Excel file
ws['A1'] = 'Quartile'
ws['B1'] = 'Threshold Value'
ws['A2'] = '1st Quartile (Q1)'
ws['B2'] = Q1
ws['A3'] = '2nd Quartile (Q2, Median)'
ws['B3'] = Q2
ws['A4'] = '3rd Quartile (Q3)'
ws['B4'] = Q3
ws['A5'] = 'Average'
ws['B5'] = average

# Add the chart image to the Excel file
img = Image('boxplot.png')
ws.add_image(img, 'D1')

# Save the Excel file
wb.save(output_file_path)

print(f"Chart and data saved to {output_file_path}")
# Out:
# 1st Quartile (Q1): 95.88
# 2nd Quartile (Q2, Median): 96.6
# 3rd Quartile (Q3): 97.04
# Average: 96.28577176298465
# Chart and data saved to /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v5 b3.xlsx

# %% [markdown]
# # **55**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from openpyxl import Workbook
from openpyxl.drawing.image import Image

# Load the Excel file
file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/v5 b5.xlsx'  # Replace with your file path
#sheet_name = 'v3 b5'  # Replace with your sheet name
df = pd.read_excel(file_path)

# Assuming the data is in column 'Best Match Score (as percentage)'
# Replace 'Best Match Score (as percentage)' with the actual column name if different
data_column = 'Best Match Score (as percentage)'

# Calculate quartiles and average
Q1 = np.percentile(df[data_column], 25)
Q2 = np.percentile(df[data_column], 50)  # Median
Q3 = np.percentile(df[data_column], 75)
average = np.mean(df[data_column])

# Print the results
print(f"1st Quartile (Q1): {Q1}")
print(f"2nd Quartile (Q2, Median): {Q2}")
print(f"3rd Quartile (Q3): {Q3}")
print(f"Average: {average}")

# Plot the data
plt.figure(figsize=(10, 6))
plt.boxplot(df[data_column], vert=False)
plt.title('Box Plot of Best Match Scores')
plt.xlabel('Best Match Score (as percentage)')
plt.savefig('boxplot.png')  # Save the plot as an image

# Create a new Excel file and save the chart
output_file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v5 b5.xlsx'
wb = Workbook()
ws = wb.active

# Add the quartiles and average to the Excel file
ws['A1'] = 'Quartile'
ws['B1'] = 'Threshold Value'
ws['A2'] = '1st Quartile (Q1)'
ws['B2'] = Q1
ws['A3'] = '2nd Quartile (Q2, Median)'
ws['B3'] = Q2
ws['A4'] = '3rd Quartile (Q3)'
ws['B4'] = Q3
ws['A5'] = 'Average'
ws['B5'] = average

# Add the chart image to the Excel file
img = Image('boxplot.png')
ws.add_image(img, 'D1')

# Save the Excel file
wb.save(output_file_path)

print(f"Chart and data saved to {output_file_path}")
# Out:
# 1st Quartile (Q1): 95.88
# 2nd Quartile (Q2, Median): 96.77
# 3rd Quartile (Q3): 97.27
# Average: 96.39469824433067
# Chart and data saved to /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v5 b5.xlsx

# %% [markdown]
# # **57**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from openpyxl import Workbook
from openpyxl.drawing.image import Image

# Load the Excel file
file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/v5 b7.xlsx'  # Replace with your file path
#sheet_name = 'v3 b5'  # Replace with your sheet name
df = pd.read_excel(file_path)

# Assuming the data is in column 'Best Match Score (as percentage)'
# Replace 'Best Match Score (as percentage)' with the actual column name if different
data_column = 'Best Match Score (as percentage)'

# Calculate quartiles and average
Q1 = np.percentile(df[data_column], 25)
Q2 = np.percentile(df[data_column], 50)  # Median
Q3 = np.percentile(df[data_column], 75)
average = np.mean(df[data_column])

# Print the results
print(f"1st Quartile (Q1): {Q1}")
print(f"2nd Quartile (Q2, Median): {Q2}")
print(f"3rd Quartile (Q3): {Q3}")
print(f"Average: {average}")

# Plot the data
plt.figure(figsize=(10, 6))
plt.boxplot(df[data_column], vert=False)
plt.title('Box Plot of Best Match Scores')
plt.xlabel('Best Match Score (as percentage)')
plt.savefig('boxplot.png')  # Save the plot as an image

# Create a new Excel file and save the chart
output_file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v5 b7.xlsx'
wb = Workbook()
ws = wb.active

# Add the quartiles and average to the Excel file
ws['A1'] = 'Quartile'
ws['B1'] = 'Threshold Value'
ws['A2'] = '1st Quartile (Q1)'
ws['B2'] = Q1
ws['A3'] = '2nd Quartile (Q2, Median)'
ws['B3'] = Q2
ws['A4'] = '3rd Quartile (Q3)'
ws['B4'] = Q3
ws['A5'] = 'Average'
ws['B5'] = average

# Add the chart image to the Excel file
img = Image('boxplot.png')
ws.add_image(img, 'D1')

# Save the Excel file
wb.save(output_file_path)

print(f"Chart and data saved to {output_file_path}")
# Out:
# 1st Quartile (Q1): 95.72
# 2nd Quartile (Q2, Median): 96.77
# 3rd Quartile (Q3): 97.34
# Average: 96.33704096561813
# Chart and data saved to /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v5 b7.xlsx

# %% [markdown]
# # **71**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from openpyxl import Workbook
from openpyxl.drawing.image import Image

# Load the Excel file
file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/v7 b1.xlsx'  # Replace with your file path
#sheet_name = 'v3 b5'  # Replace with your sheet name
df = pd.read_excel(file_path)

# Assuming the data is in column 'Best Match Score (as percentage)'
# Replace 'Best Match Score (as percentage)' with the actual column name if different
data_column = 'Best Match Score (as percentage)'

# Calculate quartiles and average
Q1 = np.percentile(df[data_column], 25)
Q2 = np.percentile(df[data_column], 50)  # Median
Q3 = np.percentile(df[data_column], 75)
average = np.mean(df[data_column])

# Print the results
print(f"1st Quartile (Q1): {Q1}")
print(f"2nd Quartile (Q2, Median): {Q2}")
print(f"3rd Quartile (Q3): {Q3}")
print(f"Average: {average}")

# Plot the data
plt.figure(figsize=(10, 6))
plt.boxplot(df[data_column], vert=False)
plt.title('Box Plot of Best Match Scores')
plt.xlabel('Best Match Score (as percentage)')
plt.savefig('boxplot.png')  # Save the plot as an image

# Create a new Excel file and save the chart
output_file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v7 b1.xlsx'
wb = Workbook()
ws = wb.active

# Add the quartiles and average to the Excel file
ws['A1'] = 'Quartile'
ws['B1'] = 'Threshold Value'
ws['A2'] = '1st Quartile (Q1)'
ws['B2'] = Q1
ws['A3'] = '2nd Quartile (Q2, Median)'
ws['B3'] = Q2
ws['A4'] = '3rd Quartile (Q3)'
ws['B4'] = Q3
ws['A5'] = 'Average'
ws['B5'] = average

# Add the chart image to the Excel file
img = Image('boxplot.png')
ws.add_image(img, 'D1')

# Save the Excel file
wb.save(output_file_path)

print(f"Chart and data saved to {output_file_path}")
# Out:
# 1st Quartile (Q1): 95.31
# 2nd Quartile (Q2, Median): 95.79
# 3rd Quartile (Q3): 96.16
# Average: 95.59978128565996
# Chart and data saved to /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v7 b1.xlsx

# %% [markdown]
# # **73**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from openpyxl import Workbook
from openpyxl.drawing.image import Image

# Load the Excel file
file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/v7 b3.xlsx'  # Replace with your file path
#sheet_name = 'v3 b5'  # Replace with your sheet name
df = pd.read_excel(file_path)

# Assuming the data is in column 'Best Match Score (as percentage)'
# Replace 'Best Match Score (as percentage)' with the actual column name if different
data_column = 'Best Match Score (as percentage)'

# Calculate quartiles and average
Q1 = np.percentile(df[data_column], 25)
Q2 = np.percentile(df[data_column], 50)  # Median
Q3 = np.percentile(df[data_column], 75)
average = np.mean(df[data_column])

# Print the results
print(f"1st Quartile (Q1): {Q1}")
print(f"2nd Quartile (Q2, Median): {Q2}")
print(f"3rd Quartile (Q3): {Q3}")
print(f"Average: {average}")

# Plot the data
plt.figure(figsize=(10, 6))
plt.boxplot(df[data_column], vert=False)
plt.title('Box Plot of Best Match Scores')
plt.xlabel('Best Match Score (as percentage)')
plt.savefig('boxplot.png')  # Save the plot as an image

# Create a new Excel file and save the chart
output_file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v7 b3.xlsx'
wb = Workbook()
ws = wb.active

# Add the quartiles and average to the Excel file
ws['A1'] = 'Quartile'
ws['B1'] = 'Threshold Value'
ws['A2'] = '1st Quartile (Q1)'
ws['B2'] = Q1
ws['A3'] = '2nd Quartile (Q2, Median)'
ws['B3'] = Q2
ws['A4'] = '3rd Quartile (Q3)'
ws['B4'] = Q3
ws['A5'] = 'Average'
ws['B5'] = average

# Add the chart image to the Excel file
img = Image('boxplot.png')
ws.add_image(img, 'D1')

# Save the Excel file
wb.save(output_file_path)

print(f"Chart and data saved to {output_file_path}")
# Out:
# 1st Quartile (Q1): 96.26
# 2nd Quartile (Q2, Median): 96.8
# 3rd Quartile (Q3): 97.14
# Average: 96.56729174591099
# Chart and data saved to /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v7 b3.xlsx

# %% [markdown]
# # **75**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from openpyxl import Workbook
from openpyxl.drawing.image import Image

# Load the Excel file
file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/v7 b5.xlsx'  # Replace with your file path
#sheet_name = 'v3 b5'  # Replace with your sheet name
df = pd.read_excel(file_path)

# Assuming the data is in column 'Best Match Score (as percentage)'
# Replace 'Best Match Score (as percentage)' with the actual column name if different
data_column = 'Best Match Score (as percentage)'

# Calculate quartiles and average
Q1 = np.percentile(df[data_column], 25)
Q2 = np.percentile(df[data_column], 50)  # Median
Q3 = np.percentile(df[data_column], 75)
average = np.mean(df[data_column])

# Print the results
print(f"1st Quartile (Q1): {Q1}")
print(f"2nd Quartile (Q2, Median): {Q2}")
print(f"3rd Quartile (Q3): {Q3}")
print(f"Average: {average}")

# Plot the data
plt.figure(figsize=(10, 6))
plt.boxplot(df[data_column], vert=False)
plt.title('Box Plot of Best Match Scores')
plt.xlabel('Best Match Score (as percentage)')
plt.savefig('boxplot.png')  # Save the plot as an image

# Create a new Excel file and save the chart
output_file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v7 b5.xlsx'
wb = Workbook()
ws = wb.active

# Add the quartiles and average to the Excel file
ws['A1'] = 'Quartile'
ws['B1'] = 'Threshold Value'
ws['A2'] = '1st Quartile (Q1)'
ws['B2'] = Q1
ws['A3'] = '2nd Quartile (Q2, Median)'
ws['B3'] = Q2
ws['A4'] = '3rd Quartile (Q3)'
ws['B4'] = Q3
ws['A5'] = 'Average'
ws['B5'] = average

# Add the chart image to the Excel file
img = Image('boxplot.png')
ws.add_image(img, 'D1')

# Save the Excel file
wb.save(output_file_path)

print(f"Chart and data saved to {output_file_path}")
# Out:
# 1st Quartile (Q1): 96.4
# 2nd Quartile (Q2, Median): 97.06
# 3rd Quartile (Q3): 97.44
# Average: 96.76906238113351
# Chart and data saved to /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v7 b5.xlsx

# %% [markdown]
# # **77**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from openpyxl import Workbook
from openpyxl.drawing.image import Image

# Load the Excel file
file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/v7 b7.xlsx'  # Replace with your file path
#sheet_name = 'v3 b5'  # Replace with your sheet name
df = pd.read_excel(file_path)

# Assuming the data is in column 'Best Match Score (as percentage)'
# Replace 'Best Match Score (as percentage)' with the actual column name if different
data_column = 'Best Match Score (as percentage)'

# Calculate quartiles and average
Q1 = np.percentile(df[data_column], 25)
Q2 = np.percentile(df[data_column], 50)  # Median
Q3 = np.percentile(df[data_column], 75)
average = np.mean(df[data_column])

# Print the results
print(f"1st Quartile (Q1): {Q1}")
print(f"2nd Quartile (Q2, Median): {Q2}")
print(f"3rd Quartile (Q3): {Q3}")
print(f"Average: {average}")

# Plot the data
plt.figure(figsize=(10, 6))
plt.boxplot(df[data_column], vert=False)
plt.title('Box Plot of Best Match Scores')
plt.xlabel('Best Match Score (as percentage)')
plt.savefig('boxplot.png')  # Save the plot as an image

# Create a new Excel file and save the chart
output_file_path = '/content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v7 b7.xlsx'
wb = Workbook()
ws = wb.active

# Add the quartiles and average to the Excel file
ws['A1'] = 'Quartile'
ws['B1'] = 'Threshold Value'
ws['A2'] = '1st Quartile (Q1)'
ws['B2'] = Q1
ws['A3'] = '2nd Quartile (Q2, Median)'
ws['B3'] = Q2
ws['A4'] = '3rd Quartile (Q3)'
ws['B4'] = Q3
ws['A5'] = 'Average'
ws['B5'] = average

# Add the chart image to the Excel file
img = Image('boxplot.png')
ws.add_image(img, 'D1')

# Save the Excel file
wb.save(output_file_path)

print(f"Chart and data saved to {output_file_path}")
# Out:
# 1st Quartile (Q1): 96.34
# 2nd Quartile (Q2, Median): 97.14
# 3rd Quartile (Q3): 97.57
# Average: 96.79929250665653
# Chart and data saved to /content/drive/MyDrive/Quran-vs-biography-semantic-similarity-CSE498/U_albert-base-v2/C_v7 b7.xlsx
